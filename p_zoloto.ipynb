# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Инструкция-по-выполнению-проекта" data-toc-modified-id="Инструкция-по-выполнению-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Инструкция по выполнению проекта</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их." data-toc-modified-id="Откройте-файлы-и-изучите-их.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Откройте файлы и изучите их.</a></span><ul class="toc-item"><li><span><a href="#Тернировочный-датасет" data-toc-modified-id="Тернировочный-датасет-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Тернировочный датасет</a></span></li><li><span><a href="#Тестовый-датасет" data-toc-modified-id="Тестовый-датасет-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Тестовый датасет</a></span></li><li><span><a href="#Исходный-датасет" data-toc-modified-id="Исходный-датасет-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Исходный датасет</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.</a></span><ul class="toc-item"><li><span><a href="#Создадим-переменные" data-toc-modified-id="Создадим-переменные-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Создадим переменные</a></span></li><li><span><a href="#Создадим-вектор-в-обучающей-выборке-для-вычесления-Recovery" data-toc-modified-id="Создадим-вектор-в-обучающей-выборке-для-вычесления-Recovery-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Создадим вектор в обучающей выборке для вычесления Recovery</a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана правильно</a></span></li><li><span><a href="#Найдем-MAE-между-расчётами-и-значением-признака" data-toc-modified-id="Найдем-MAE-между-расчётами-и-значением-признака-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Найдем MAE между расчётами и значением признака</a></span></li><li><span><a href="#Удалим-вектор-'rougher.output.recovery_calc'-созданный-для-рассчета" data-toc-modified-id="Удалим-вектор-'rougher.output.recovery_calc'-созданный-для-рассчета-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>Удалим вектор 'rougher.output.recovery_calc' созданный для рассчета</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-5.2.6"><span class="toc-item-num">5.2.6&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span><ul class="toc-item"><li><span><a href="#Создадим-новый-датафрейм,-в-нем-будут-находиться-признаки,-недоступные-в-тестовой-выборке." data-toc-modified-id="Создадим-новый-датафрейм,-в-нем-будут-находиться-признаки,-недоступные-в-тестовой-выборке.-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Создадим новый датафрейм, в нем будут находиться признаки, недоступные в тестовой выборке.</a></span></li><li><span><a href="#Найдем-и-изучим-недоступные-признаки" data-toc-modified-id="Найдем-и-изучим-недоступные-признаки-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Найдем и изучим недоступные признаки</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Проведите-предобработку-данных." data-toc-modified-id="Проведите-предобработку-данных.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проведите предобработку данных.</a></span><ul class="toc-item"><li><span><a href="#Проверим--датасеты-на-дубликаты-и-пропуски" data-toc-modified-id="Проверим--датасеты-на-дубликаты-и-пропуски-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Проверим  датасеты на дубликаты и пропуски</a></span></li><li><span><a href="#Добавим-недостающие-данные-в-df_test" data-toc-modified-id="Добавим-недостающие-данные-в-df_test-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Добавим недостающие данные в df_test</a></span></li><li><span><a href="#Обработка-пропусков-в-датасетах" data-toc-modified-id="Обработка-пропусков-в-датасетах-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Обработка пропусков в датасетах</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы." data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.</a></span><ul class="toc-item"><li><span><a href="#Концетрация-Аu-(золота)-на-различных-этапах-очистки" data-toc-modified-id="Концетрация-Аu-(золота)-на-различных-этапах-очистки-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Концетрация Аu (золота) на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Фильтруем-данные-для-золота" data-toc-modified-id="Фильтруем-данные-для-золота-6.1.1.1"><span class="toc-item-num">6.1.1.1&nbsp;&nbsp;</span>Фильтруем данные для золота</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-сырье" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-сырье-6.1.1.2"><span class="toc-item-num">6.1.1.2&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в сырье</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах-6.1.1.3"><span class="toc-item-num">6.1.1.3&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в хвостах</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.1.1.4"><span class="toc-item-num">6.1.1.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Концетрация-Ag-(серебра)-на-различных-этапах-очистки" data-toc-modified-id="Концетрация-Ag-(серебра)-на-различных-этапах-очистки-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Концетрация Ag (серебра) на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Фильтруем-данные-для-серебра" data-toc-modified-id="Фильтруем-данные-для-серебра-6.1.2.1"><span class="toc-item-num">6.1.2.1&nbsp;&nbsp;</span>Фильтруем данные для серебра</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-сырье" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-сырье-6.1.2.2"><span class="toc-item-num">6.1.2.2&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в сырье</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах-6.1.2.3"><span class="toc-item-num">6.1.2.3&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в хвостах</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.1.2.4"><span class="toc-item-num">6.1.2.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Концетрация-Pb-(свинца)-на-различных-этапах-очистки" data-toc-modified-id="Концетрация-Pb-(свинца)-на-различных-этапах-очистки-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Концетрация Pb (свинца) на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Фильтруем-данные-для-серебра" data-toc-modified-id="Фильтруем-данные-для-серебра-6.1.3.1"><span class="toc-item-num">6.1.3.1&nbsp;&nbsp;</span>Фильтруем данные для серебра</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-сырье" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-сырье-6.1.3.2"><span class="toc-item-num">6.1.3.2&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в сырье</a></span></li><li><span><a href="#Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах" data-toc-modified-id="Визуализация-концетрации-на-различных-этапах-очистки-в-хвостах-6.1.3.3"><span class="toc-item-num">6.1.3.3&nbsp;&nbsp;</span>Визуализация концетрации на различных этапах очистки в хвостах</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.1.3.4"><span class="toc-item-num">6.1.3.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li></ul></li><li><span><a href="#Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span><ul class="toc-item"><li><span><a href="#Визуализация-концентрации-размера-сырья-на-входе-флотации-train-и-test" data-toc-modified-id="Визуализация-концентрации-размера-сырья-на-входе-флотации-train-и-test-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Визуализация концентрации размера сырья на входе флотации train и test</a></span></li><li><span><a href="#Визуализация-концентрации-размера-сырья-на-входе-финальной-очистки-train-и-test" data-toc-modified-id="Визуализация-концентрации-размера-сырья-на-входе-финальной-очистки-train-и-test-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Визуализация концентрации размера сырья на входе финальной очистки train и test</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span><ul class="toc-item"><li><span><a href="#Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-сырье" data-toc-modified-id="Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-сырье-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Найдем суммарную концентрацию металлов (ag, pb, sol, au) в сырье</a></span><ul class="toc-item"><li><span><a href="#Визуализация-суммарной-концетрации-веществ-в-сырье" data-toc-modified-id="Визуализация-суммарной-концетрации-веществ-в-сырье-6.3.1.1"><span class="toc-item-num">6.3.1.1&nbsp;&nbsp;</span>Визуализация суммарной концетрации веществ в сырье</a></span></li></ul></li><li><span><a href="#Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-черновом-концентрате" data-toc-modified-id="Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-черновом-концентрате-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Найдем суммарную концентрацию металлов (ag, pb, sol, au) в черновом концентрате</a></span><ul class="toc-item"><li><span><a href="#Визуализация-суммарной-концетрации-веществ-в-черновом-концентрате" data-toc-modified-id="Визуализация-суммарной-концетрации-веществ-в-черновом-концентрате-6.3.2.1"><span class="toc-item-num">6.3.2.1&nbsp;&nbsp;</span>Визуализация суммарной концетрации веществ в черновом концентрате</a></span></li></ul></li><li><span><a href="#Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-финальном-концентрате" data-toc-modified-id="Найдем-суммарную-концентрацию-металлов-(ag,-pb,-sol,-au)-в-финальном-концентрате-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Найдем суммарную концентрацию металлов (ag, pb, sol, au) в финальном концентрате</a></span><ul class="toc-item"><li><span><a href="#Визуализация-суммарной-концетрации-веществ--в-финальном-концентрате" data-toc-modified-id="Визуализация-суммарной-концетрации-веществ--в-финальном-концентрате-6.3.3.1"><span class="toc-item-num">6.3.3.1&nbsp;&nbsp;</span>Визуализация суммарной концетрации веществ  в финальном концентрате</a></span></li></ul></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li><li><span><a href="#Проверим-есть-ли-выбросы-=0-в-тестовом-датасете" data-toc-modified-id="Проверим-есть-ли-выбросы-=0-в-тестовом-датасете-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Проверим есть ли выбросы =0 в тестовом датасете</a></span><ul class="toc-item"><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.3.5.1"><span class="toc-item-num">6.3.5.1&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Удаляем-аномалии" data-toc-modified-id="Удаляем-аномалии-6.3.6"><span class="toc-item-num">6.3.6&nbsp;&nbsp;</span>Удаляем аномалии</a></span><ul class="toc-item"><li><span><a href="#Убедимся-что-выбросы-отсуствуют-в-тренировочной-выборке" data-toc-modified-id="Убедимся-что-выбросы-отсуствуют-в-тренировочной-выборке-6.3.6.1"><span class="toc-item-num">6.3.6.1&nbsp;&nbsp;</span>Убедимся что выбросы отсуствуют в тренировочной выборке</a></span></li></ul></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-6.3.7"><span class="toc-item-num">6.3.7&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE.</a></span><ul class="toc-item"><li><span><a href="#Описание-функции-sMAPE" data-toc-modified-id="Описание-функции-sMAPE-7.0.1.1"><span class="toc-item-num">7.0.1.1&nbsp;&nbsp;</span>Описание функции sMAPE</a></span></li><li><span><a href="#Функция-sMAPE" data-toc-modified-id="Функция-sMAPE-7.0.1.2"><span class="toc-item-num">7.0.1.2&nbsp;&nbsp;</span>Функция sMAPE</a></span></li></ul></li><li><span><a href="#Подготовим-данные-для-модели" data-toc-modified-id="Подготовим-данные-для-модели-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Подготовим данные для модели</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия-|-Linear-regression" data-toc-modified-id="Линейная-регрессия-|-Linear-regression-7.0.3.1"><span class="toc-item-num">7.0.3.1&nbsp;&nbsp;</span>Линейная регрессия | Linear regression</a></span></li><li><span><a href="#Случайный-лес-|-Random-Forest" data-toc-modified-id="Случайный-лес-|-Random-Forest-7.0.3.2"><span class="toc-item-num">7.0.3.2&nbsp;&nbsp;</span>Случайный лес | Random Forest</a></span></li><li><span><a href="#Древо-решений-|-Decision-Tree" data-toc-modified-id="Древо-решений-|-Decision-Tree-7.0.3.3"><span class="toc-item-num">7.0.3.3&nbsp;&nbsp;</span>Древо решений | Decision Tree</a></span></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-7.0.3.4"><span class="toc-item-num">7.0.3.4&nbsp;&nbsp;</span>ВЫВОД:</a></span></li></ul></li><li><span><a href="#Проверим-модель-Случайный-лес-|-Random-Forest-на-тестовой-выборке" data-toc-modified-id="Проверим-модель-Случайный-лес-|-Random-Forest-на-тестовой-выборке-7.0.4"><span class="toc-item-num">7.0.4&nbsp;&nbsp;</span>Проверим модель Случайный лес | Random Forest на тестовой выборке</a></span></li><li><span><a href="#Проверим-модель-на-адекватность" data-toc-modified-id="Проверим-модель-на-адекватность-7.0.5"><span class="toc-item-num">7.0.5&nbsp;&nbsp;</span>Проверим модель на адекватность</a></span></li></ul></li><li><span><a href="#ВЫВОД:" data-toc-modified-id="ВЫВОД:-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span><strong>ВЫВОД:</strong></a></span></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общий вывод:</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Технологический процесс

# %% [markdown]
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Опишем каждую стадию:**

# %% [markdown]
# **1. Флотация**

# %% [markdown]
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
#
#
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).

# %% [markdown]
# **2. Очистка**

# %% [markdown]
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# **Технологический процесс**

# %% [markdown]
# - **Rougher feed** — исходное сырье
# - **Rougher additions (или reagent additions)*** — флотационные реагенты: **Xanthate, Sulphate, Depressant**
# ** **Xanthate** — ксантогенат (промотер, или активатор флотации);
# ** **Sulphate** — сульфат (на данном производстве сульфид натрия);
# ** **Depressant** — депрессант (силикат натрия).
# - **Rougher process (англ. «грубый процесс»)** — флотация
# - **Rougher tails** — отвальные хвосты
# - **Float banks** — флотационная установка
# - **Cleaner process** — очистка
# - **Rougher Au** — черновой концентрат золота
# - **Final Au** — финальный концентрат золота

# %% [markdown]
# **Параметры этапов**

# %% [markdown]
# - **air amount** — объём воздуха
# - **fluid levels** — уровень жидкости
# - **feed size** — размер гранул сырья
# - **feed rate** — скорость подачи

# %% [markdown]
# **Наименование признаков**

# %% [markdown]
# Наименование признаков должно быть такое:

# %% [markdown]
# **[этап].[тип_параметра].[название_параметра]**

# %% [markdown]
# Пример: **rougher.input.feed_ag**

# %% [markdown]
# Возможные значения для блока **[этап]:**

# %% [markdown]
# - **rougher** — флотация
# - **primary_cleaner** — первичная очистка
# - **secondary_cleaner** — вторичная очистка
# - **final** — финальные характеристики

# %% [markdown]
# Возможные значения для блока **[тип_параметра]:**

# %% [markdown]
# - **input** — параметры сырья
# - **output** — параметры продукта
# - **state** — параметры, характеризующие текущее состояние этапа
# - **calculation** — расчётные характеристики

# %% [markdown]
# ## Инструкция по выполнению проекта

# %% [markdown]
# 1. **Подготовьте данные**
#
#
# - Откройте файлы и изучите их.
# - Путь к файлам:
# /datasets/gold_recovery_train_new.csv. Скачать датасет
# /datasets/gold_recovery_test_new.csv. Скачать датасет
# /datasets/gold_recovery_full_new.csv. Скачать датасет
#   - Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
#   - Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
#   - Проведите предобработку данных.
#
#
# 2. **Проанализируйте данные**
#
#   - Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
#   - Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#   - Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
#
# 3. **Постройте модель**
#
#   - Напишите функцию для вычисления итоговой sMAPE.
#   - Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откройте файлы и изучите их.

# %%
import pandas as pd


from matplotlib import pyplot as plt
import seaborn as sns


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_absolute_error
from sklearn.preprocessing import StandardScaler

from collections import namedtuple
import numpy as np

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %% [markdown]
# #### Тернировочный датасет

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
df_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df_train.shape
# Out:
# (14149, 87)

# %% [markdown]
# #### Тестовый датасет

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
df_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
df_test.shape
# Out:
# (5290, 53)

# %% [markdown]
# #### Исходный датасет

# %%
df_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df_full.shape
# Out:
# (19439, 87)

# %% [markdown]
# #### ВЫВОД:

# %% [markdown]
# Данные открыты, просмотрены и изучены.

# %% [markdown]
# ### Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.

# %% [markdown]
# **Эффективность обогащения рассчитывается по формуле**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Значения переменных формулы**
#
#
# **C** - доля золота в концентрате после флотации/очистки (rougher.output.concentrate_au)
#
#
# **F** - доля золота в сырье/концентрате до флотации/очистки (rougher.input.feed_au)
#
#
# **T** - доля золота в отвальных хвостах после флотации/очистки (rougher.output.tail_au)

# %% [markdown]
# #### Создадим переменные

# %%
C = df_train['rougher.output.concentrate_au']
F = df_train['rougher.input.feed_au']
T = df_train['rougher.output.tail_au']

# %% [markdown]
# #### Создадим вектор в обучающей выборке для вычесления Recovery

# %%
df_train['rougher.output.recovery_calc'] = (C * (F - T)) / (F * (C - T)) * 100

# %% [markdown]
# #### Проверим, что эффективность обогащения рассчитана правильно
#
# Сравним среднее занчение вектора **'rougher.output.recovery'** и среднее значение полученного вычесления **'rougher.output.recovery_calc'**

# %%
sravnenie_recovery = pd.DataFrame(index=['Средняя эффективность обогащения'],
                                 columns=['rougher.output.recovery','rougher.output.recovery_calc'])

sravnenie_recovery['rougher.output.recovery'] = df_train['rougher.output.recovery'].mean()
sravnenie_recovery['rougher.output.recovery_calc'] = df_train['rougher.output.recovery_calc'].mean() 

sravnenie_recovery
# Out:
#                                   rougher.output.recovery  \
# Средняя эффективность обогащения                82.704502
#
#                                   rougher.output.recovery_calc
# Средняя эффективность обогащения                     82.704502

# %% [markdown]
# #### Найдем MAE между расчётами и значением признака

# %%
mean_absolute_error(df_train['rougher.output.recovery'],df_train['rougher.output.recovery_calc'])
# Out:
# 9.73512347450521e-15

# %% [markdown]
# #### Удалим вектор 'rougher.output.recovery_calc' созданный для рассчета

# %%
df_train.drop('rougher.output.recovery_calc', axis=1, inplace=True)

# %%
#Убедимся что он удален
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# #### ВЫВОД:
#
#
#  1. Средняя эффективность обогащения вычисления среднее значение полученного вычесления **'rougher.output.recovery_calc'**  совпадает со средней эффективностью обогащения **'rougher.output.recovery'**
#
#
#  2. Опираясь на низкий показатель **MAE** и равенство в пункте **1.**, делаем вывод - **рассчеты верны**

# %% [markdown]
# ### Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %% [markdown]
# #### Создадим новый датафрейм, в нем будут находиться признаки, недоступные в тестовой выборке.

# %%
new_df = df_train.copy()

# %% [markdown]
# #### Найдем и изучим недоступные признаки

# %%
new_df = new_df.drop(columns=list(df_test.columns))

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %%
new_df.head()
# Out:
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.concentrate_au  \
# 0                      5.507324                    42.192020
# 1                      5.257781                    42.701629
# 2                      5.383759                    42.657501
# 3                      4.858634                    42.689819
# 4                      4.939416                    42.774141
#
#    final.output.recovery  final.output.tail_ag  final.output.tail_pb  \
# 0              70.541216             10.411962              0.895447
# 1              69.266198             10.462676              0.927452
# ...

# %% [markdown]
# #### ВЫВОД:
#
#
#  - В тесте отсутсвтуют **34** вектора **'output'** - параметры прокудкта
#
#
#  - В тесте отсутсвтуют целевые признаки:
#
#
#    1.)**'rougher.output.recovery'**([флотация].[параметры продукта].[эффективность обогащения])
#
#
#
#    2.)**'final.output.recovery'**([финальные характеристики].[параметры продукта].[эффективность обогащения])

# %% [markdown]
# ### Проведите предобработку данных.

# %% [markdown]
# ####  Проверим  датасеты на дубликаты и пропуски

# %% [markdown]
# **df_full** — исходный датасет

# %%
df_full.duplicated().sum()
# Out:
# 0

# %%
x = pd.DataFrame(df_full.isna().sum(), columns = ['Пропуски']).reset_index()

y = pd.DataFrame(round(df_full.isna().mean()*100, 2), columns = ['Доля_пропусков_%']).reset_index()

result_df_full = pd.merge(x, y, how='left', on='index')

result_df_full = result_df_full.rename(columns={'index': 'Признаки'})

# %%
result_df_full.style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# **df_train** - тренировочный датасет

# %%
df_full.duplicated().sum()
# Out:
# 0

# %%
x = pd.DataFrame(df_train.isna().sum(), columns = ['Пропуски']).reset_index()

y = pd.DataFrame(round(df_train.isna().mean()*100, 2), columns = ['Доля_пропусков_%']).reset_index()

result_df_train = pd.merge(x, y, how='left', on='index')

result_df_train = result_df_train.rename(columns={'index': 'Признаки'})

# %%
result_df_train.style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# **df_test** — тестовый датасет

# %%
x = pd.DataFrame(df_test.isna().sum(), columns = ['Пропуски']).reset_index()

y = pd.DataFrame(round(df_test.isna().mean()*100, 2), columns = ['Доля_пропусков_%']).reset_index()

result_df_test = pd.merge(x, y, how='left', on='index')

result_df_test = result_df_test.rename(columns={'index': 'Признаки'})

# %%
result_df_test.style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Добавим недостающие данные в df_test

# %%
df_test = df_test.merge(df_full[['final.output.recovery', 'rougher.output.recovery', 'date']], how='left', on='date')

# %%
df_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# #### Обработка пропусков в датасетах

# %% [markdown]
# В целевых признаках **'rougher.output.recovery'** и **'final.output.recovery'** пропуски отсутсвтуют, поэтому заменим все пропуски предыдущими значениями **(в тз указано: "cоседние по времени параметры часто похожи")**

# %%
df_train = df_train.fillna(method='ffill')
df_test = df_test.fillna(method='ffill')
df_full = df_full.fillna(method='ffill')

# %%
print('Кол-во строк с пропусками в data_train', df_train.isna().sum().sum())
print('Кол-во строк с пропусками в data_test', df_test.isna().sum().sum())
print('Кол-во строк с пропусками в data_full', df_full.isna().sum().sum())
# Out:
# Кол-во строк с пропусками в data_train 0
# Кол-во строк с пропусками в data_test 0
# Кол-во строк с пропусками в data_full 0

# %% [markdown]
# #### ВЫВОД:

# %% [markdown]
# 1. В датасетах отсутсвтуют дубликаты
#
#
# 2. Добавлены недостающие данные в тестовый дататасет
#
#
# 3. Заменены пропуски. В целевых признаках **'rougher.output.recovery' и 'final.output.recovery'** пропуски отсутсвтуют, поэтому заменили все пропуски предыдущими значениями (в тз указано: "cоседние по времени параметры часто похожи")

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.

# %% [markdown]
# #### Концетрация Аu (золота) на различных этапах очистки

# %% [markdown]
# ##### Фильтруем данные для золота

# %%
df_au = df_full[['rougher.input.feed_au',
                 'rougher.output.concentrate_au',
                 'primary_cleaner.output.concentrate_au',   
                 'final.output.concentrate_au']]

df_au_tail = df_full[['rougher.output.tail_au',
                      'primary_cleaner.output.tail_au',
                      'secondary_cleaner.output.tail_au',
                      'final.output.tail_au']]

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в сырье

# %%
sns.set(style="darkgrid")

fig, ax1 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_au.mean().plot(ax=ax1, 
                  subplots=True, 
                  fontsize=10, 
                  color='goldenrod')

ax1.set_title('Золото (Au)', fontsize=15)
ax1.set_ylabel('Концентрация металла', fontsize=10)
ax1.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

df_au['rougher.input.feed_au'].hist(bins=25, 
                                    label='rougher.input.feed_au',
                                    alpha=0.8)

df_au['rougher.output.concentrate_au'].hist(bins=25, 
                                            label='rougher.output.concentrate_au', 
                                            alpha=0.5)

df_au['primary_cleaner.output.concentrate_au'].hist(bins=25, 
                                                    label='primary_cleaner.output.concentrate_au', 
                                                    alpha=0.5)

df_au['final.output.concentrate_au'].hist(bins=25, 
                                          label='final.output.concentrate_au', 
                                          alpha=0.5)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
plt.title('Диаграмма концентрации золота (Au)')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %%
df_au[['rougher.input.feed_au', 
       'rougher.output.concentrate_au', 
       'primary_cleaner.output.concentrate_au', 
       'final.output.concentrate_au']].mean()
# Out:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в хвостах

# %%
sns.set(style="darkgrid")

fig, ax1 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_au_tail.mean().plot(ax=ax1, 
                       subplots=True, 
                       fontsize=10, 
                       color='goldenrod')

ax1.set_title('Золото (Au)', fontsize=15)
ax1.set_ylabel('Концентрация металла', fontsize=10)
ax1.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
df_au_tail[['rougher.output.tail_au', 
            'primary_cleaner.output.tail_au', 
            'secondary_cleaner.output.tail_au', 
            'final.output.tail_au']].mean()
# Out:
# rougher.output.tail_au              1.816391
# primary_cleaner.output.tail_au      3.914179
# secondary_cleaner.output.tail_au    4.339625
# final.output.tail_au                3.042467
# dtype: float64

# %% [markdown]
# #####  ВЫВОД:

# %% [markdown]
# 1. Концентрация золота равномерно увеличивается на каждом этапе обработки сырья.
#
#
# 2. Концентрация золота в отвалах тоже увеличивается, но на финальном этапе немного уменьшается.
#
#
# 3. На графике концентрации сырья имеются значения равные нулю, веротяно это выбросы.

# %% [markdown]
# #### Концетрация Ag (серебра) на различных этапах очистки

# %% [markdown]
# ##### Фильтруем данные для серебра

# %%
df_ag = df_full[['rougher.input.feed_ag',
                 'rougher.output.concentrate_ag', 
                 'primary_cleaner.output.concentrate_ag', 
                 'final.output.concentrate_ag']]

df_ag_tail = df_full[['rougher.output.tail_ag',
                      'primary_cleaner.output.tail_ag',
                      'secondary_cleaner.output.tail_ag',
                      'final.output.tail_ag']]

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в сырье

# %%
sns.set(style="darkgrid")

fig, ax2 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_ag.mean().plot(ax=ax2, 
                  subplots=True, 
                  fontsize=10, 
                  color='grey')

ax2.set_title('Серебро (Ag)', fontsize=15)
ax2.set_ylabel('Концентрация металла', fontsize=10)
ax2.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

df_ag['rougher.input.feed_ag'].hist(bins=50, 
                                    label='rougher.input.feed_ag',
                                    alpha=0.8)

df_ag['rougher.output.concentrate_ag'].hist(bins=50, 
                                            label='rougher.output.concentrate_ag', 
                                            alpha=0.5)

df_ag['primary_cleaner.output.concentrate_ag'].hist(bins=50, 
                                                    label='primary_cleaner.output.concentrate_ag', 
                                                    alpha=0.5)

df_ag['final.output.concentrate_ag'].hist(bins=50, 
                                          label='final.output.concentrate_ag', 
                                          alpha=0.5)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
plt.title('Диаграмма концентрации серебра (Ag)')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper right')
plt.show()

# %%
df_ag[['rougher.input.feed_ag',
       'rougher.output.concentrate_ag', 
       'primary_cleaner.output.concentrate_ag', 
       'final.output.concentrate_ag']].mean()
# Out:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168387
# dtype: float64

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в хвостах

# %%
sns.set(style="darkgrid")

fig, ax2 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_ag_tail.mean().plot(ax=ax2, subplots=True, fontsize=10, color='grey')


ax2.set_title('Серебро (Ag)', fontsize=15)
ax2.set_ylabel('Концентрация металла', fontsize=10)
ax2.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
df_ag_tail[['rougher.output.tail_ag',
            'primary_cleaner.output.tail_ag',
            'secondary_cleaner.output.tail_ag',
            'final.output.tail_ag']].mean()
# Out:
# rougher.output.tail_ag               5.589064
# primary_cleaner.output.tail_ag      16.145888
# secondary_cleaner.output.tail_ag    14.586720
# final.output.tail_ag                 9.688487
# dtype: float64

# %% [markdown]
# #####  ВЫВОД:

# %% [markdown]
# 1. Концетрация серебра сначала повышается и после понижается на всех этапах обработки сырья
#
#
# 2. Концентрация серебра в отвалах сначала увеличивается, но после понижается.
#
#
# 3. На графике концентрации сырья имеются значения равные нулю, веротяно это выбросы.

# %% [markdown]
# #### Концетрация Pb (свинца) на различных этапах очистки

# %% [markdown]
# ##### Фильтруем данные для серебра

# %%
df_pb = df_full[['rougher.input.feed_pb',
                 'rougher.output.concentrate_pb', 
                 'primary_cleaner.output.concentrate_pb', 
                 'final.output.concentrate_pb']]

df_pb_tail = df_full[['rougher.output.tail_pb',
                      'primary_cleaner.output.tail_pb',
                      'secondary_cleaner.output.tail_pb',
                      'final.output.tail_pb']]

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в сырье

# %%
sns.set(style="darkgrid")

fig, ax3 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_pb.mean().plot(ax=ax3, subplots=True, fontsize=10, color='black')
ax3.set_title('Свинец (Pb)', fontsize=15)
ax3.set_ylabel('Концентрация металла', fontsize=10)
ax3.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

df_pb['rougher.input.feed_pb'].hist(bins=50, 
                                    label='rougher.input.feed_pb', 
                                    alpha=0.8)

df_pb['rougher.output.concentrate_pb'].hist(bins=50, 
                                            label='rougher.output.concentrate_pb', 
                                            alpha=0.5)

df_pb['primary_cleaner.output.concentrate_pb'].hist(bins=50, 
                                                    label='primary_cleaner.output.concentrate_pb', 
                                                    alpha=0.5)

df_pb['final.output.concentrate_pb'].hist(bins=50, 
                                          label='final.output.concentrate_pb', 
                                          alpha=0.5)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
plt.title('Диаграмма концентрации свинца (Pb)')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper right')
plt.show()

# %%
df_pb[['rougher.input.feed_pb',
       'rougher.output.concentrate_pb', 
       'primary_cleaner.output.concentrate_pb', 
       'final.output.concentrate_pb']].mean()
# Out:
# rougher.input.feed_pb                    3.585096
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.810317
# final.output.concentrate_pb              9.978821
# dtype: float64

# %% [markdown]
# ##### Визуализация концетрации на различных этапах очистки в хвостах

# %%
sns.set(style="darkgrid")

fig, ax3 = plt.subplots(1, 1, linewidth=3, figsize=(15, 5))

df_pb_tail.mean().plot(ax=ax3, 
                       subplots=True,
                       fontsize=10,
                       color='black')

ax3.set_title('Свинец (Pb)', fontsize=15)
ax3.set_ylabel('Концентрация металла', fontsize=10)
ax3.set_xlabel('Стадии очистки', fontsize=15)

plt.suptitle('Изменение концентрации металла на различных этапах очистки', fontsize=15, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Изменение концентрации металла на различных этапах очистки')

# %%
df_pb_tail[['rougher.output.tail_pb',
            'primary_cleaner.output.tail_pb',
            'secondary_cleaner.output.tail_pb',
            'final.output.tail_pb']].mean()
# Out:
# rougher.output.tail_pb              0.645782
# primary_cleaner.output.tail_pb      3.433558
# secondary_cleaner.output.tail_pb    5.776428
# final.output.tail_pb                2.694897
# dtype: float64

# %% [markdown]
# #####  ВЫВОД:

# %% [markdown]
# 1. Концетрация свинца на всех этапах обработки сырья повышается.
#
#
# 2. Концентрация свинца в отвалах сначала увеличивается, но после понижается.
#
#
# 3. На графике концентрации сырья имеются значения равные нулю, веротяно это выбросы.

# %% [markdown]
# ### Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %% [markdown]
# #### Визуализация концентрации размера сырья на входе флотации train и test

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15, 5))

sns.kdeplot(df_train['rougher.input.feed_size'], 
            label='train rougher.input.feed_size', 
            alpha=0.5, 
            shade=True)

sns.kdeplot(df_test['rougher.input.feed_size'], 
            label='test rougher.input.feed_size', 
            alpha=0.7, 
            shade=True)

plt.xlim([0, 175])
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности непрерывной величины')
plt.legend(loc='upper right')
plt.show()



print('train:\n')
print(df_train['rougher.input.feed_size'].describe())
print('_____________________________________________')
print('train:\n')
print(df_test['rougher.input.feed_size'].describe())
print('_____________________________________________')
print('\n')
print('Дисперсия тренировочной выборки:',np.var(df_train['rougher.input.feed_size']))
print('Дисперсия тестовой выборки:',np.var(df_test['rougher.input.feed_size']))
# Out:
# train:
#
# count    14149.000000
# mean        60.239856
# std         23.005310
# min          9.659576
# 25%         48.966751
# 50%         55.269784
# 75%         66.007526
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64
# _____________________________________________
# train:
#
# count    5290.000000
# mean       55.952754
# std        19.080334
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# 75%        62.451165
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64
# _____________________________________________
#
#
# Дисперсия тренировочной выборки: 529.2068649509116
# Дисперсия тестовой выборки: 363.99032899257844

# %% [markdown]
# #### Визуализация концентрации размера сырья на входе финальной очистки train и test

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15, 5))

sns.kdeplot(df_train['primary_cleaner.input.feed_size'], 
            label='train primary_cleaner.input.feed_size', 
            alpha=0.3, 
            shade=True)

sns.kdeplot(df_test['primary_cleaner.input.feed_size'],  
            label='test primary_cleaner.input.feed_size', 
            alpha=0.3, 
            shade=True)

plt.xlim([5, 10])
plt.xlabel('Значения')
plt.ylabel('Плотность вероятности')
plt.legend(loc='upper right')
plt.show()

print('train:\n')
print(df_train['primary_cleaner.input.feed_size'].describe())
print('_____________________________________________')
print('test:\n')
print(df_test['primary_cleaner.input.feed_size'].describe())
print('_____________________________________________')
print('\n')
print('Дисперсия тренировочной выборки:',np.var(df_train['primary_cleaner.input.feed_size']))
print('Дисперсия тестовой выборки:',np.var(df_test['primary_cleaner.input.feed_size']))
# Out:
# train:
#
# count    14149.000000
# mean         7.322310
# std          0.614062
# min          1.080000
# 25%          6.960000
# 50%          7.290000
# 75%          7.700000
# max         10.470000
# Name: primary_cleaner.input.feed_size, dtype: float64
# _____________________________________________
# test:
#
# count    5290.000000
# mean        7.266339
# std         0.610219
# min         5.650000
# 25%         6.890000
# 50%         7.250000
# 75%         7.600000
# max        15.500000
# Name: primary_cleaner.input.feed_size, dtype: float64
# _____________________________________________
#
#
# Дисперсия тренировочной выборки: 0.3770458141328873
# Дисперсия тестовой выборки: 0.3722965577722183

# %% [markdown]
# #### ВЫВОД:

# %% [markdown]
# 1. Сильных отличий в распределнии не наблюдается.
#
# 2. Небольшая разница дисперсий выборок также гороворит нам что нет сильных отличий в распределении.

# %% [markdown]
# ###  Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# #### Найдем суммарную концентрацию металлов (ag, pb, sol, au) в сырье

# %%
sum_r_input_feed = df_full[['rougher.input.feed_ag', 
                   'rougher.input.feed_pb', 
                   'rougher.input.feed_sol', 
                   'rougher.input.feed_au']].sum(axis=1)

# %%
sum_r_input_feed
# Out:
# 0        51.680034
# 1        50.659114
# 2        50.609929
# 3        51.061546
# 4        47.859163
#            ...
# 19434    53.415050
# 19435    53.696482
# 19436    54.589604
# 19437    54.027355
# 19438    53.535054
# Length: 19439, dtype: float64

# %%
print('Сумма веществ в сырье:', sum_r_input_feed.sum())
# Out:
# Сумма веществ в сырье: 1114258.825317531

# %% [markdown]
# ##### Визуализация суммарной концетрации веществ в сырье

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_r_input_feed.hist(bins=75, 
              label='Сумма металлов (ag, pb, sol, au)',
              alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в сырье', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### Найдем суммарную концентрацию металлов (ag, pb, sol, au) в черновом концентрате

# %%
sum_r_output_conc = df_full[['rougher.output.concentrate_pb', 
                   'rougher.output.concentrate_ag', 
                   'rougher.output.concentrate_sol', 
                   'rougher.output.concentrate_au']].sum(axis=1)

# %%
sum_r_output_conc
# Out:
# 0        66.424950
# 1        67.012710
# 2        66.103793
# 3        65.752751
# 4        65.908382
#            ...
# 19434    70.781325
# 19435    70.539603
# 19436    55.376330
# 19437    69.201689
# 19438    69.544003
# Length: 19439, dtype: float64

# %%
print('Сумма веществ в черновом концентрате:', sum_r_input_feed.sum())
# Out:
# Сумма веществ в черновом концентрате: 1114258.825317531

# %% [markdown]
# ##### Визуализация суммарной концетрации веществ в черновом концентрате

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_r_output_conc.hist(bins=75, 
              label='Сумма металлов (ag, pb, sol, au)',
              alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в черновом концентрате', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### Найдем суммарную концентрацию металлов (ag, pb, sol, au) в финальном концентрате

# %%
sum_f_output_conc = df_full[['final.output.concentrate_pb', 
                   'final.output.concentrate_ag', 
                   'final.output.concentrate_sol', 
                   'final.output.concentrate_au']].sum(axis=1)

# %%
sum_f_output_conc
# Out:
# 0        63.644396
# 1        63.957723
# 2        64.311180
# 3        63.573449
# 4        64.004667
#            ...
# 19434    68.098589
# 19435    68.274362
# 19436    68.226068
# 19437    68.200449
# 19438    68.353154
# Length: 19439, dtype: float64

# %%
print('Сумма веществ в финальном концентрате:', sum_f_output_conc.sum())
# Out:
# Сумма веществ в финальном концентрате: 1334557.7918941458

# %% [markdown]
# ##### Визуализация суммарной концетрации веществ  в финальном концентрате

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_f_output_conc.hist(bins=75, 
              label='Сумма металлов (ag, pb, sol, au)',
              alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в финальном концентрате', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### ВЫВОД:

# %% [markdown]
# 1. В сырье выбросы отсутсвуют
#
#
# 2. В черновом концетрате имеется значительное кол-во выбросов = 0.
#
#
# 3. В финальном концтетрате имеется незначительное кол-во выбросов = 0.
#
#
# - Выбросы могли появиться в результате сбоя оборудования, они могут повлиять на результаты моделей
#
#
# - Стоит удалить выбросы чернового концтетрата в обучающей выборке(train).

# %% [markdown]
# #### Проверим есть ли выбросы =0 в тестовом датасете

# %%
test_sum = df_test[['rougher.input.feed_ag', 
                    'rougher.input.feed_pb', 
                    'rougher.input.feed_sol', 
                    'rougher.input.feed_au']].sum(axis=1)

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

test_sum.hist(bins=75, 
              label='Сумма металлов (ag, pb, sol, au)',
              alpha=0.8)

plt.suptitle('Суммарная концентрация веществ сырья тетстовой выборке', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ##### ВЫВОД:

# %% [markdown]
# Выбросы =0 отсутствуют в тестовой выборке

# %% [markdown]
# #### Удаляем аномалии

# %% [markdown]
# Выбросы =0 наблюдались на разных стадиях и этапах в:
#
# 1. 'rougher.output.concentrate'
#
# 2. 'primary_cleaner.output.concentrate'
#
# 3. 'final.output.concentrate'

# %%
#au_train
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_au'] < 1].index)
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_au'] < 1].index)
df_train = df_train.drop(df_train[df_train['final.output.concentrate_au'] < 1].index)

#ag_train
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_ag'] < 1].index)
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_ag'] < 1].index)
df_train = df_train.drop(df_train[df_train['final.output.concentrate_ag'] < 1].index)

#pg_train
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_pb'] < 1].index)
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_pb'] < 1].index)
df_train = df_train.drop(df_train[df_train['final.output.concentrate_pb'] < 1].index)

#sol_train
df_train = df_train.drop(df_train[df_train['rougher.output.concentrate_sol'] < 1].index)
df_train = df_train.drop(df_train[df_train['primary_cleaner.output.concentrate_sol'] < 1].index)
df_train = df_train.drop(df_train[df_train['final.output.concentrate_sol'] < 1].index)

# %% [markdown]
# ##### Убедимся что выбросы отсуствуют в тренировочной выборке

# %%
sum_r_output_conc_new = df_train[['rougher.output.concentrate_pb', 
                                  'rougher.output.concentrate_ag', 
                                  'rougher.output.concentrate_sol', 
                                  'rougher.output.concentrate_au']].sum(axis=1)

sum_p_c_o_conc = df_train[['primary_cleaner.output.concentrate_pb',
                           'primary_cleaner.output.concentrate_ag',
                           'primary_cleaner.output.concentrate_sol',
                           'primary_cleaner.output.concentrate_au']].sum(axis=1)


sum_f_c_o_conc = df_train[['final.output.concentrate_au',
                           'final.output.concentrate_ag',
                           'final.output.concentrate_pb',
                           'final.output.concentrate_sol']].sum(axis=1)

# %% [markdown]
# **'rougher.output.concentrate'**

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_r_output_conc_new.hist(bins=75, 
                           label='Сумма металлов (ag, pb, sol, au)',
                           alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в черновом концентрате', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **'primary_cleaner.output.concentrate'**

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_f_c_o_conc.hist(bins=75, 
                    label='Сумма металлов (ag, pb, sol, au)',
                    alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в первичной очистке', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **'final.output.concentrate'**

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(15,5))

sum_p_c_o_conc.hist(bins=75, 
                    label='Сумма металлов (ag, pb, sol, au)',
                    alpha=0.8)

plt.suptitle('Суммарная концентрация веществ в финальном концетрате', fontsize=15, fontweight='bold')
plt.xlabel('Значения')
plt.ylabel('Количество')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### ВЫВОД:

# %% [markdown]
# Выбросы =0 удалены

# %% [markdown]
# ## Модель

# %% [markdown]
# #### Напишите функцию для вычисления итоговой sMAPE.

# %% [markdown]
# ##### Описание функции sMAPE

# %% [markdown]
# **sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).**
#
#
# Она похожа на **MAE**, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
# Метрика sMAPE вычисляется так:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Обозначения:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Значение предсказания для объекта с порядковым номером i, например, в тестовой выборке.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Количество объектов в выборке.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Суммирование по всем объектам выборки (i меняется от 1 до N).

# %% [markdown]
# **Нужно спрогнозировать сразу две величины:**
#
#
# - эффективность обогащения чернового концентрата **rougher.output.recovery**;
# - эффективность обогащения финального концентрата **final.output.recovery**.

# %% [markdown]
# **Итоговая метрика складывается из двух величин:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Функция sMAPE

# %% [markdown]
# **Функции sMAPE**

# %%
def smape(target_actual, target_predictions):
    numerator = np.abs(target_actual - target_predictions)
    denominator = (np.abs(target_actual) + np.abs(target_predictions)) / 2 
    
    return 1 / len(target_actual) * np.sum(numerator / denominator) * 100

# %%
def final_smape(target_actual, target_predictions):
    target_actual_rougher = target_actual['rougher.output.recovery']
    target_actual_final = target_actual['final.output.recovery']
    
    target_predictions_rougher = target_predictions[:, 0]
    target_predictions_final = target_predictions[:, 1]
    
    return 0.25 * smape(target_actual_rougher, target_predictions_rougher) + 0.75 * smape(target_actual_final, target_predictions_final)

# %% [markdown]
# #### Подготовим данные для модели

# %%
#Целевые признаки
TARGETS = ['rougher.output.recovery', 'final.output.recovery']

#Рандом
RS = 12345

#scorer для кросс-валидации 
smape_scorer = make_scorer(final_smape, greater_is_better=False)

# %%
# удалим вектор с датой
df_test.drop(['date'], axis=1, inplace=True)

# %%
#удалим из тренировочной выборки те признаки, которых нет в тестовой
df_train = df_train.drop(set(df_train.columns)-set(df_test.columns), axis=1)

# %%
features_train = df_train.drop(TARGETS, axis='columns')
target_train = df_train[TARGETS]
features_test = df_test.drop(TARGETS, axis='columns')
target_test = df_test[TARGETS]

# %%
display(features_train.shape)
display(target_train.shape)

display(features_test.shape)
display(target_test.shape)
# Out:
# (13425, 52)
# (13425, 2)
# (5290, 52)
# (5290, 2)

# %% [markdown]
# #### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# ##### Линейная регрессия | Linear regression

# %%
#%%time

#model = LinearRegression()
#model.fit(features_train, target_train)
#smape = cross_val_score(model, features_train, target_train, cv=5, scoring=smape_scorer).mean()
#print('Лучшее значение sMAPE для линейной регрессии:', -smape)
#print()

# %% [markdown]
# ![%D0%BB%D0%B8%D0%BD_%D1%80%D0%B5%D0%B3_%D1%81%D0%B1_%D0%BF_2.png](attachment:%D0%BB%D0%B8%D0%BD_%D1%80%D0%B5%D0%B3_%D1%81%D0%B1_%D0%BF_2.png)

# %%
model_linear_regression_smape = 9.924693866768104
print('Лучшее значение sMAPE линейной регрессии:', model_linear_regression_smape)
# Out:
# Лучшее значение sMAPE линейной регрессии: 9.924693866768104

# %% [markdown]
# ##### Случайный лес | Random Forest

# %%
#%%time

#param_grid = {'n_estimators': range(10, 51, 10,),
              #'max_depth': range(1, 6, 1)}
    
#smape_scorer = make_scorer(final_smape, greater_is_better=False)

#model = RandomForestRegressor(random_state=RS)
#search = GridSearchCV(model, param_grid ,n_jobs=-1, cv=5, scoring=smape_scorer)
#search.fit(features_train, target_train)
#smape_random_forest_regressor = -search.best_score_
#print('Лучшее значение sMAPE для случайного леса: {} при значениях гиперпараметров: {}'
      #.format(-search.best_score_, search.best_params_))
#print()

# %% [markdown]
# ![%D1%81%D0%BB%D1%83%D1%87_%D0%BB%D0%B5%D1%81_%D1%81%D0%B1_%D0%BF2.png](attachment:%D1%81%D0%BB%D1%83%D1%87_%D0%BB%D0%B5%D1%81_%D1%81%D0%B1_%D0%BF2.png)

# %%
model_random_forest_regressor_smape = 8.565479518824077
print('Лучшее значение sMAPE случайного леса:', model_random_forest_regressor_smape)
print('Лучшие значения гиперпараметров max_depth: {}, n_estimators: {}'.format(3,5))
# Out:
# Лучшее значение sMAPE случайного леса: 8.565479518824077
# Лучшие значения гиперпараметров max_depth: 3, n_estimators: 5

# %% [markdown]
# ##### Древо решений | Decision Tree

# %%
#%%time

#param_grid = {'max_depth': range(1, 16, 1)}

#model = DecisionTreeRegressor(random_state=RS)
#search = GridSearchCV(model, param_grid, cv=5, scoring=smape_scorer)
#search.fit(features_train, target_train)
#print('Лучшее значение sMAPE для дерева решений: {} при значении гиперпараметра: {}'
      #.format(-search.best_score_, search.best_params_))
#print()

# %% [markdown]
# ![%D0%B4%D1%80_%D1%80%D0%B5%D1%88_%D1%81%D0%B1%D0%BF2.png](attachment:%D0%B4%D1%80_%D1%80%D0%B5%D1%88_%D1%81%D0%B1%D0%BF2.png)

# %%
model_decision_tree_regressor_smape = 8.872638215842619
print('Лучшее значение sMAPE случайного леса:', model_decision_tree_regressor_smape)
print('Лучшее значение гиперпараметра max_depth: {}'.format(1))
# Out:
# Лучшее значение sMAPE случайного леса: 8.872638215842619
# Лучшее значение гиперпараметра max_depth: 1

# %% [markdown]
# ##### ВЫВОД:

# %% [markdown]
# Наилучший показатель **sMAPE** дала модель **Случайный лес | Random Forest**:
#
# 1. **sMAPE** случайного леса: **6.466717237823896**
# 2. Значения гиперпараметров **max_depth: 3, n_estimators: 5**

# %% [markdown]
# #### Проверим модель Случайный лес | Random Forest на тестовой выборке

# %%
model = RandomForestRegressor(max_depth=3, n_estimators=5, random_state=RS) 
model.fit(features_train, target_train)
predictions_test = model.predict(features_test)

print('sMAPE для тестовых данных:', final_smape(target_test, predictions_test))
# Out:
# sMAPE для тестовых данных: 9.347359294622894

# %% [markdown]
# #### Проверим модель на адекватность

# %% [markdown]
# **Используем модель DummyRegressor() для работы с регрессией.**

# %%
dummy = DummyRegressor(strategy="mean")

dummy.fit(features_train, target_train)
predictions_test = dummy.predict(features_test)

print('sMAPE адекватной модели:', final_smape(target_test, predictions_test))
# Out:
# sMAPE адекватной модели: 9.764362669971486

# %% [markdown]
# ### **ВЫВОД:**

# %%
itog_sravnenie = pd.DataFrame(index=['sMAPE'],
                                 columns=['Случайный лес(train)',
                                          'Случайный лес(test)',
                                          'Адекватной модели'])
itog_sravnenie['Случайный лес(train)'] = 8.565479518824077
itog_sravnenie['Случайный лес(test)'] = 9.347359294622894
itog_sravnenie['Адекватной модели'] = 9.764362669971486
                                     
itog_sravnenie
# Out:
#        Случайный лес(train)  Случайный лес(test)  Адекватной модели
# sMAPE               8.56548             9.347359           9.764363

# %% [markdown]
# 1. Лучший показатель **sMAPE** дала модель **Сулчайный лес|Random Forest** с гиперпараметрами:
#  - **max_depth: 3**
#  - **n_estimators: 5**
#
#
#
# 2. Показатель **sMAPE** на тестовой выборке оказался ниже чем показатель **sMAPE** адекватной модели

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# 1. Была проведена подготовка данных
#
#
# 2. Убедились что эффективность обогащения рассчитана правильно
#
#
# 3. Проанализированны признаки, недоступные в тестовой выборке.
#
#
# 4. Была произведенна предобработка данных:
#
# -  Добавлены недостающие данные в тестовый дататасет
# -  Заменены пропуски. В целевых признаках **'rougher.output.recovery'** и **'final.output.recovery'** пропуски отсутсвтуют, поэтому заменили все пропуски предыдущими значениями.
#
#
# 5. Произведен анализ **металлов (Au, Ag, Pb)**:
#
# - Концентрация металлов **(Au, Ag, Pb)** на различных этапах очистки.
# - Распределение размеров гранул сырья на обучающей и тестовой выборках.
# - Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# - Удалены выбросы в тестовой выборке
#
# 6. Модель:
#
# - Написанны функции для рассчета **sMAPE**
# - Подготовленны данные для обучения
# - Обучены модели (Линейная регрессия, случайный лес, древо решений)
# - Найдена наилучшая модель на обучающей выборке: Случайный лес ( с показателем  **sMAPE**: **8.565479518824077** и гиперпараметрами: **max_depth: 3, n_estimators: 5** )
# - Прозведенно тестирование наилучшей модели на тестовой выборке (**sMAPE**: **9.347359294622894**)
# - Проверили модель на адекватность при помощи константной модели **DummyRegressor()**
